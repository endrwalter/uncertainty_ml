# %%
from lib.u_functions import run_tte_evaluation, plot_comprehensive_dashboard

eval_df, df_results = run_tte_evaluation('../results/classification/mci_ad_conversion/label_bl_36m/aggregated/patient_mean_probs_label_bl_36m_mci_ad_conversion_model.csv',
    '../data/adni/adni_baseline_only_36m.csv')
print(df_results)
plot_comprehensive_dashboard(df_results, eval_df)
# Out:
#   Time to Event  Pos Cases    AUC    PRC    MCC  Req. Threshold  TP  FN   TN  \
# 0          0-6m         22  0.911  0.723  0.473           0.633  18   4  116
# 1         6-12m         47  0.861  0.687  0.507           0.527  40   7  105
# 2        12-18m         35  0.876  0.685  0.477           0.542  29   6  108
# 3        18-24m         37  0.779  0.579  0.318           0.378  31   6   80
# 4        30-36m         29  0.800  0.462  0.312           0.420  24   5   85
#
#    FP  Sensitivity  Specificity  Tot Unc
# 0  28        0.818        0.806    0.712
# 1  39        0.851        0.729    0.799
# 2  36        0.829        0.750    0.780
# 3  64        0.838        0.556    0.808
# 4  59        0.828        0.590    0.853
