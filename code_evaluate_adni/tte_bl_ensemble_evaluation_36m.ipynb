# %%
from lib.u_functions import run_tte_evaluation, plot_comprehensive_dashboard

eval_df, df_results = run_tte_evaluation('../results/classification/mci_ad_conversion/label/aggregated/patient_mean_probs_label_mci_ad_conversion_model.csv',
    '../data/adni/adni_baseline_only_36m.csv')
print(df_results)
plot_comprehensive_dashboard(df_results, eval_df)
# Out:
#   Time to Event  Pos Cases    AUC    PRC    MCC  Req. Threshold  TP  FN   TN  \
# 0          0-6m         22  0.905  0.714  0.464           0.614  18   4  115
# 1         6-12m         47  0.861  0.692  0.494           0.524  40   7  103
# 2        12-18m         35  0.875  0.688  0.463           0.529  29   6  106
# 3        18-24m         37  0.775  0.568  0.318           0.384  31   6   80
# 4        30-36m         29  0.797  0.466  0.307           0.415  24   5   84
#
#    FP  Sensitivity  Specificity  Tot Unc
# 0  29        0.818        0.799    0.711
# 1  41        0.851        0.715    0.805
# 2  38        0.829        0.736    0.784
# 3  64        0.838        0.556    0.817
# 4  60        0.828        0.583    0.858
