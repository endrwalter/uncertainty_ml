# %%
from lib.u_functions import run_tte_evaluation, plot_comprehensive_dashboard

eval_df, df_results = run_tte_evaluation('../results/classification/mci_ad_conversion/label_bl_24m/aggregated/patient_mean_probs_label_bl_24m_mci_ad_conversion_model.csv',
    '../data/adni/adni_baseline_only_24m.csv')
print(df_results)
plot_comprehensive_dashboard(df_results, eval_df)
# Out:
#   Time to Event  Pos Cases    AUC    PRC    MCC  Req. Threshold  TP  FN   TN  \
# 0          0-6m         22  0.849  0.403  0.334           0.448  18   4  139
# 1         6-12m         47  0.799  0.413  0.405           0.396  40   7  129
# 2        12-18m         35  0.788  0.359  0.269           0.317  29   6  107
# 3        18-24m         37  0.687  0.271  0.176           0.247  31   6   77
#
#     FP  Sensitivity  Specificity  Tot Unc
# 0   57        0.818        0.709    0.895
# 1   67        0.851        0.658    0.935
# 2   89        0.829        0.546    0.920
# 3  119        0.838        0.393    0.901
